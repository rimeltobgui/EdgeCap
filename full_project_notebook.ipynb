# %% [markdown]
# <a href="https://colab.research.google.com/github/rimeltobgui/EdgeCap/blob/main/full_project_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Cloning our github repo

# %%
# !git clone https://github.com/rimeltobgui/EdgeCap.git
# Out:
# Cloning into 'EdgeCap'...
# remote: Enumerating objects: 99, done.
# remote: Counting objects: 100% (99/99), done.
# remote: Compressing objects: 100% (96/96), done.
# remote: Total 99 (delta 33), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (99/99), 43.28 MiB | 13.60 MiB/s, done.
# Resolving deltas: 100% (33/33), done.

# %% [markdown]
# ### Setting EdgeCap as current working directory for the rest of the code

# %%
import os
os.chdir('/content/EdgeCap')

# %% [markdown]
# ### Installing requirenents

# %%
# !pip install -q -r requirements.txt
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 MB 14.1 MB/s eta 0:00:00

# %% [markdown]
# ### Displaying our sample images used for evaluation

# %%
import os
from PIL import Image
from IPython.display import display

image_paths = [
    "test_images/soccer.jpg",
    "test_images/dog.jpg",
    "test_images/classroom.png"
]
# Optional display loop (Jupyter/IPython)
for path in image_paths:
    img = Image.open(path).convert("RGB")
    display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=612x408>
# <PIL.Image.Image image mode=RGB size=612x408>
# <PIL.Image.Image image mode=RGB size=1351x866>

# %% [markdown]
# ## Running EdgeCap inference

# %% [markdown]
# ###EdgeCap32: Clip-Vit-b-32 + mapper + distilgpt2

# %%
# !python scripts/edgecap32-inference.py
# Out:
# 2025-05-05 12:54:24.620315: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746449664.644613    4406 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746449664.651933    4406 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-05 12:54:24.676882: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# ###EdgeCap16: TinyCLIP-ViT-39M-16 + mapper + distilgpt2

# %%
# !python scripts/edgecap16-inference.py
# Out:
# 2025-05-05 13:29:03.847524: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746451743.889705   12964 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746451743.902444   12964 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-05 13:29:03.947282: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# ## EdgeCap Validation on Flicker30k

# %% [markdown]
# ## EdgeCap32

# %% [markdown]
# ## EdgeCap16

# %% [markdown]
# ## EdgeCap Mapper Training on Flicker30k

# %% [markdown]
# ## EdgeCap32

# %% [markdown]
# ## EdgeCap16
